# %% [markdown]
# ## Month 3 Week 1
# Recaps on what we learnt

# %% [markdown]
# ## List
# - List are ordered collection of items. You can add, remove and access elements

# %%
import pandas as pd

# %%
employee_1 = 'Micheal'
employee_2 = 'Frank'
employee_3 = 'Tolulope'
employee_4 = 'Abraham'

print(f'Hello {employee_1}, Welcome on board. We are happy to have you')
print(f'Hello {employee_2}, Welcome on board. We are happy to have you')
# Out:
# Hello Micheal, Welcome on board. We are happy to have you
# Hello Frank, Welcome on board. We are happy to have you

# %%
employees = ['Mubarak', 'Nduka', 'Tolulope', 'Abraham', 'Oladayo']

message = "We are happy to have you"
for employee in employees:
    print(f'Hello {employee}, {message}')
# Out:
# Hello Mubarak, We are happy to have you
# Hello Nduka, We are happy to have you
# Hello Tolulope, We are happy to have you
# Hello Abraham, We are happy to have you
# Hello Oladayo, We are happy to have you

# %%
employee_info = [
    ['Mubarak', 'Sani', 30, 'Male', 1.76, 'Complicated', True],
    ['Nduka', 'Sani', 30, 'Male', 1.76, 'Complicated', True],
    ['Tolulope', 'Sani', 30, 'Female', 3.76, 'Complicated', True],
]

employee_info[2][3]
# Out:
# 'Female'

# %%
employee_info_dict = {
    '001': {
        'firstname': 'Mubarak',
        'lastname': 'Sani',
        'age': 30,
        'gender': 'Male',
        'height': 1.76,
        'marital_status': 'Complicated',
        'is_active': True
    },
    '002':{
        'firstname': 'Tolulope',
        'lastname': 'Sani',
        'age': 30,
        'gender': 'Female',
        'height': 1.76,
        'marital_status': 'Complicated',
        'is_active': True
    }
}

# %%
employee_info_dict.get('001')['firstname']
# Out:
# 'Mubarak'

# %% [markdown]
# - Structured Data : Organized into rows and column
# - Semi-Structured Data :
# - Unstructured Data

# %%
employee_table = pd.DataFrame(employee_info_dict).T  #Transpose
employee_table
# Out:
#     firstname lastname age  gender height marital_status is_active
# 001   Mubarak     Sani  30    Male   1.76    Complicated      True
# 002  Tolulope     Sani  30  Female   1.76    Complicated      True

# %%
employee_table.to_csv('Employee Table.csv')

# %%
# Todo
# Create a system that allows new employee to signup, login, logout using data types and data structures and other python concepts
# When

#Signup: We need  to store information for easy retrival
#Login: A Mechanism that would take their information and check it against the data
#Logout: A Mechanism that would delete their session information
#DeleteData: a mechanism that would take id and remove other information

# For signup we need first_name, last_name, age, marital status, gender, height, is_active

# %%
employee_system = {}

first_name = input('Enter your first name: ').title()
last_name = input('Enter your last name: ').title()
age = int(input('Enter your age: '))
marital_status = input('Enter your marital status: ').title()
gender = input('Enter your gender: ').title()
height = float(input('Enter your height: '))

# Store in the dictionary and automatically give an ID and is_active

employee_system.update(
    {
        'firstname': first_name,
        'lastname': last_name,
        'age': age,
        'gender': gender,
        'height': height,
        'marital_status': marital_status,
        'is_active': True
    }
)
