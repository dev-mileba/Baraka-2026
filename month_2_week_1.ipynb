# %% [markdown]
# ## Functions

# %%
# Basic Function structure
def greet(): # defining the function
    print("Hello world")
    print("i love python")

greet() # Calling the function
# Out:
# Hello world
# i love python

# %% [markdown]
# ## Functions with Parameters

# %%
def greet_person(name): # defining the function
    print(f"Hello, {name}! ")

greet_person("Michael")
greet_person("Daniel")
# Out:
# Hello, Michael!
# Hello, Daniel!

# %% [markdown]
# ## Function with return statement

# %%
def add_numbers(a, b):
    return a + b

# result = add_numbers(2,3)
# print(result)

def square(number):
    return number ** 2

result = square(5)
print(result)
# Out:
# 25

# %%
def get_stats(numbers):
    total = sum(numbers)
    avg = total / len(numbers)
    return total, avg

sum_nums, avg_nums = get_stats([10, 20, 30, 40, 50, 60, 70, 80, 90])
print(f"Total : {sum_nums}")
print(f"Average : {avg_nums}")
# Out:
# Total : 450
# Average : 50.0

# %% [markdown]
# ## Default Parameters

# %%
def greet_hi(name, greeting="Good morning"):
    return f"{greeting} {name}!"

greet_hi("Michael")
# Out:
# 'Good morning Michael!'

# %%
# Positional Arguments
def intro(name, age, city):
    print(f"My name is {name} and I am {age} years old. I live in {city}")

intro("Micheal", 18, "Coventry")
# Out:
# My name is Micheal and I am 18 years old. I live in Coventry

# %%
# arbitrary arguments
def sum_nums(*args):
    return sum(args)
sum_nums(1, 2, 3, 6)
# Out:
# 12

# %% [markdown]
# ## Functions with Loops and If Statement

# %%
# functions that count even numbers from a list of numbers
def count_evens(numbers):
    count = 0
    for num in numbers:
        if num % 2 == 0:
            count += 1
    return count

result_even = count_evens([1, 2, 3, 4, 5,6,8])
print(result_even)
# Out:
# 4

# %% [markdown]
# ## Part 1 : List - Ordered Collections
#
# ### What are list?
#
# List are ordered, mutable collections that can store multiple items.
