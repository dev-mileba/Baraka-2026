# %%
# Let's create our first variable
# Scenario: You're analyzing a small online store performance

store_name = "Awolowo Republic" #string
daily_visitors = 1250 #Integer
conversion_rate = 0.045 #float


print("Store Name:", store_name)
print("Daily Visitors:", daily_visitors)
print("Conversion Rate:", conversion_rate)
# Out:
# Store Name: Awolowo Republic
# Daily Visitors: 1250
# Conversion Rate: 0.045

# %%
# variable names should not contain spaces
my_name = "Mileba Micheal"
# variable names cannot start with numbers or other special characters
# Use descriptive names: customer_count, average_age

# %%
temperature_celsius = 28
humidity_percent = 75
rainfall_mm = 12.5
wind_speed_kmh = 15

print("Today's Weather in Kaduna:")
print("Temperature:", temperature_celsius, "C")
print("Humidity:", humidity_percent, "%")
print("Rainfall:", rainfall_mm, "mm")
print("Wind Speed:", wind_speed_kmh, "km/h")
# Out:
# Today's Weather in Kaduna:
# Temperature: 28 C
# Humidity: 75 %
# Rainfall: 12.5 mm
# Wind Speed: 15 km/h

# %%
#print(type(my_name))

# %%
# string formatting
#print(type(my_name))
print(my_name, "is my name")
# Out:
# Mileba Micheal is my name

# %%
dir(my_name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
my_name * 5
# Out:
# 'Mileba MichealMileba MichealMileba MichealMileba MichealMileba Micheal'

# %%
type(input("w"))
# Out:
# str

# %%
not (5 > 3 and 2 < 1)
# Out:
# True
