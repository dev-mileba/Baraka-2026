# %% [markdown]
# ## Functions

# %%
# Basic Function structure
def greet(): # defining the function
    print("Hello world")
    print("i love python")

greet() # Calling the function
# Out:
# Hello world
# i love python

# %% [markdown]
# ## Functions with Parameters

# %%
def greet_person(name): # defining the function
    print(f"Hello, {name}! ")

greet_person("Michael")
greet_person("Daniel")
# Out:
# Hello, Michael!
# Hello, Daniel!

# %% [markdown]
# ## Function with return statement

# %%
def add_numbers(a, b):
    return a + b

# result = add_numbers(2,3)
# print(result)

def square(number):
    return number ** 2

result = square(5)
print(result)
# Out:
# 25

# %%
def get_stats(numbers):
    total = sum(numbers)
    avg = total / len(numbers)
    return total, avg

sum_nums, avg_nums = get_stats([10, 20, 30, 40, 50, 60, 70, 80, 90])
print(f"Total : {sum_nums}")
print(f"Average : {avg_nums}")
# Out:
# Total : 450
# Average : 50.0

# %% [markdown]
# ## Default Parameters

# %%
def greet_hi(name, greeting="Good morning"):
    return f"{greeting} {name}!"

greet_hi("Michael")
# Out:
# 'Good morning Michael!'

# %%
# Positional Arguments
def intro(name, age, city):
    print(f"My name is {name} and I am {age} years old. I live in {city}")

intro("Micheal", 18, "Coventry")
# Out:
# My name is Micheal and I am 18 years old. I live in Coventry

# %%
# arbitrary arguments
def sum_nums(*args):
    return sum(args)
sum_nums(1, 2, 3, 6)
# Out:
# 12

# %% [markdown]
# ## Functions with Loops and If Statement

# %%
# functions that count even numbers from a list of numbers
def count_evens(numbers):
    count = 0
    for num in numbers:
        if num % 2 == 0:
            count += 1
    return count

result_even = count_evens([1, 2, 3, 4, 5,6,8])
print(result_even)
# Out:
# 4

# %% [markdown]
# ## Part 1 : List - Ordered Collections
#
# ### What are list?
#
# List are ordered, mutable collections that can store multiple items.

# %%
names = ['Kehinde', 'Rema', 'Vivian', 'Bright']

# %% [markdown]
# ## Accessing List Elements

# %%
print (names[-1])
print (names[1: 3])
# Out:
# Bright
# ['Rema', 'Vivian']

# %% [markdown]
# ## Modifying Lists

# %%
# names.append("James")
# names.insert(0, "Debby")
# names.extend(['Eberechi', 'Ngozi'])
# names.pop()

print(names)
# Out:
# ['Kehinde', 'Rema', 'Vivian', 'Bright']

# %%
help(names.pop)
# Out:
# Help on built-in function pop:
#
# pop(index=-1, /) method of builtins.list instance
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %% [markdown]
# ## Useful List Methods

# %%
list_numbers = [3,1,4,1,5,9,2,6]
list_numbers.sort()
print(list_numbers)

list_numbers.reverse()
print(list_numbers)
# Out:
# [1, 1, 2, 3, 4, 5, 6, 9]
# [9, 6, 5, 4, 3, 2, 1, 1]

# %% [markdown]
# ## Part 2: Tuples - Immutable Sequences
#
# ### What are Tuples?
# Tuples are immutables sequence

# %%
coordinates = (10, 20)
person = ('Alice', 25, 'Engineer')
single_item = (42,)
empty_tuple = ()

point = 10, 20, 30 #the comma is what makes a tuple — not the parentheses. Parentheses are just for grouping/clarity.
type(point)
# Out:
# tuple

# %% [markdown]
# ## Part 3: Dictionaries - Key-Value Pairs
#
# ### What are Dictionaries
#
# Dictionaries store data as key-value pairs

# %%
shopping = {
    'Garri': 300,
    'Chicken':600,
    'Pepper':200,
    'Water':400
}

# %%
student = {
    'name': 'Michael',
    'age': 25,
    'major': 'Agricultural Engineer'
}

# %% [markdown]
# ### Accessing Dictionary Values

# %%
print(student['name'])
print(student['age'])
print(student['major'])

student.get('name')
# Out:
# Michael
# 25
# Agricultural Engineer
# 'Michael'

# %% [markdown]
# ### Modifying Dictionary Value

# %%
shopping['vegetable'] = 400

# %%
del shopping['Garri']

# %%
print(shopping)
# Out:
# {'Chicken': 600, 'Pepper': 200, 'Water': 400, 'vegetable': 400}

# %% [markdown]
# ### Dictionary Operation with Loops

# %% [markdown]
# ## Part 4: Sets - Unique Collections
#
# ### What are Sets?
#
# Sets are unordered collection of unique items

# %%
student_set = {'Kehinde', 'Rema', 'Vivian', 'Bright'}
type(student_set)
# Out:
# set

# %%
'Rema' in student_set
# Out:
# True

# %% [markdown]
# ### Set Operations

# %%
fruit = {'apple', 'banana', 'orange'}
fruit.add('pear')
fruit.update(['mango', 'grape'])
fruit.remove('apple')
fruit.discard('pear')
print(fruit)
# Out:
# {'grape', 'banana', 'mango', 'orange'}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

union = set1 | set2 #or set1.union(set2)
intersection = set1 & set2
difference = set1 - set2 #what is in set1 and not set2
print(union)
print(intersection)
print(difference)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
